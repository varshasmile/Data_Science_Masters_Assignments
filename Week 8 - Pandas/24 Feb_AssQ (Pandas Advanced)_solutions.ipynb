# %%
import pandas as pd

# %% [markdown]
# Q1. List any five functions of the pandas library with execution.

# %% [markdown]
# i. read_csv(): This function is used to read data from a CSV file and create a DataFrame.

# %%
df = pd.read_csv('services.csv')

df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %% [markdown]
# ii. head(): This function returns the first n rows of a DataFrame, where n is specified as an argument. It is useful for quickly inspecting the structure and contents of the DataFrame.

# %%
df.head(3)
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
#
#                                          description  \
# 0  A walk-in center for older adults that provide...
# 1  Provides training and job placement to eligibl...
# 2  Offers supportive counseling services to San M...
#
#                                          eligibility email  ...  \
# ...

# %% [markdown]
# iii. info(): This function provides a summary of the DataFrame, including the number of rows, column names, data types, and memory usage. It is helpful for getting an overview of the data and checking for missing values or inconsistent data types.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       23 non-null     int64
#  1   location_id              23 non-null     int64
#  2   program_id               0 non-null      float64
#  3   accepted_payments        1 non-null      object
#  4   alternate_name           1 non-null      object
#  5   application_process      23 non-null     object
#  6   audience                 14 non-null     object
#  7   description              23 non-null     object
#  8   eligibility              21 non-null     object
#  9   email                    1 non-null      object
#  10  fees                     21 non-null     object
#  11  funding_sources          21 non-null     object
#  12  interpretation_services  1 non-null      object
#  13  keywords                 21 non-null     object
# ...

# %% [markdown]
# iv. describe(): This function generates descriptive statistics of the DataFrame, such as count, mean, standard deviation, minimum, maximum, and quartile values for numerical columns. It provides a summary of the central tendency, dispersion, and shape of the distribution of the data.

# %%
df.describe()
# Out:
#              id  location_id  program_id
# count  23.00000    23.000000         0.0
# mean   12.00000    11.956522         NaN
# std     6.78233     6.711444         NaN
# min     1.00000     1.000000         NaN
# 25%     6.50000     6.500000         NaN
# 50%    12.00000    12.000000         NaN
# 75%    17.50000    17.500000         NaN
# max    23.00000    22.000000         NaN

# %% [markdown]
# v. to_csv(): This function is used to write the contents of a DataFrame to a CSV file.

# %%
new_file = df.describe()

# Write the new DataFrame to a new CSV file
new_file.to_csv('described_services.csv', index=False)

# %% [markdown]
# Q2. Given a Pandas DataFrame df with columns 'A', 'B', and 'C', write a Python function to re-index the
# DataFrame with a new index that starts from 1 and increments by 2 for each row.

# %%
# assume given df
df = pd.DataFrame({'A': [10, 20, 30], 'B': [40, 50, 60], 'C': [70, 80, 90]})
df
# Out:
#     A   B   C
# 0  10  40  70
# 1  20  50  80
# 2  30  60  90

# %%
# reindexed df
def reindexed_df(df):
    df.reset_index(drop=True, inplace=True)
    df.index = df.index * 2 + 1
    return df

reindexed_df(df)
# Out:
#     A   B   C
# 1  10  40  70
# 3  20  50  80
# 5  30  60  90

# %% [markdown]
# Q3. Q3. You have a Pandas DataFrame df with a column named 'Values'. Write a Python function that
# iterates over the DataFrame and calculates the sum of the first three values in the 'Values' column. The
# function should print the sum to the console.
# For example, if the 'Values' column of df contains the values [10, 20, 30, 40, 50], your function should
# calculate and print the sum of the first three values, which is 60.

# %%
df = pd.DataFrame({'Values' : [10, 20, 30, 40, 50]})
df
# Out:
#    Values
# 0      10
# 1      20
# 2      30
# 3      40
# 4      50

# %%
def iterate_df(df):
    sum_df = 0
    for index, row in df.iterrows():
        sum_df += row['Values']
        if index == 2:
            break
    print("Sum of the first three values:", sum_df)
    
iterate_df(df)
# Out:
# Sum of the first three values: 60

# %% [markdown]
# Q4. Given a Pandas DataFrame df with a column 'Text', write a Python function to create a new column
# 'Word_Count' that contains the number of words in each row of the 'Text' column.

# %%
df = pd.DataFrame({'Text': ['Hello, how are you?', 'I am doing great!', 'Python is awesome']})
df
# Out:
#                   Text
# 0  Hello, how are you?
# 1    I am doing great!
# 2    Python is awesome

# %%
def word_count(df):
     # Define a lambda function to count words in a text
    count_words = lambda text: len(str(text).split())

    # Apply the lambda function to the 'Text' column and assign the result to the 'Word_Count' column
    df['Word_Count'] = df['Text'].apply(count_words)

    return df

word_count(df)
# Out:
#                   Text  Word_Count
# 0  Hello, how are you?           4
# 1    I am doing great!           4
# 2    Python is awesome           3

# %% [markdown]
# Q5. How are DataFrame.size() and DataFrame.shape() different?

# %% [markdown]
# DataFrame.size(): This method returns the total number of elements in the DataFrame. It calculates the size by multiplying the number of rows (DataFrame.shape[0]) by the number of columns (DataFrame.shape[1]). The size() method provides the total count of elements, including both data values and missing/NaN values. It returns a single integer value.
# Example:

# %%
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
print(df.size)
# Out:
# 6

# %% [markdown]
# DataFrame.shape(): This attribute returns a tuple that represents the dimensions of the DataFrame. It returns the number of rows as the first element and the number of columns as the second element. The shape attribute does not include missing/NaN values in its calculation. It returns a tuple of integers.
# Example:

# %%
df.shape               #  DataFrame has 3 rows and 2 columns.
# Out:
# (3, 2)

# %% [markdown]
# Q6. Which function of pandas do we use to read an excel file?

# %% [markdown]
# To read an Excel file in pandas, we can use the pandas.read_excel() function.

# %%
excel_file = pd.read_excel('LUSID Excel - Setting up your market data.xlsx')
excel_file.head(3)
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2          Unnamed: 3 Unnamed: 4  \
# 0         NaN         NaN         NaN                 NaN        NaN
# 1         NaN         NaN         NaN  Datetimes in LUSID        NaN
# 2         NaN         NaN         NaN                 NaN        NaN
#
#   Unnamed: 5  Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0        NaN         NaN        NaN        NaN        NaN
# 1        NaN         NaN        NaN        NaN        NaN
# 2        NaN         NaN        NaN        NaN        NaN

# %% [markdown]
# Q7. You have a Pandas DataFrame df that contains a column named 'Email' that contains email
# addresses in the format 'username@domain.com'. Write a Python function that creates a new column
# 'Username' in df that contains only the username part of each email address.
# The username is the part of the email address that appears before the '@' symbol. For example, if the
# email address is 'john.doe@example.com', the 'Username' column should contain 'john.doe'. Your
# function should extract the username from each email address and store it in the new 'Username'
# column.

# %%
df = pd.DataFrame({'Email': ['john.doe@example.com', 'jane.smith@example.com', 'james.brown@example.com']})
df
# Out:
#                      Email
# 0     john.doe@example.com
# 1   jane.smith@example.com
# 2  james.brown@example.com

# %%
def username(df):
    df['Username'] = df['Email'].str.split('@').str[0]
    
    return df

username(df)
# Out:
#                      Email     Username
# 0     john.doe@example.com     john.doe
# 1   jane.smith@example.com   jane.smith
# 2  james.brown@example.com  james.brown

# %% [markdown]
# Q8. You have a Pandas DataFrame df with columns 'A', 'B', and 'C'. Write a Python function that selects
# all rows where the value in column 'A' is greater than 5 and the value in column 'B' is less than 10. The
# function should return a new DataFrame that contains only the selected rows.
# For example, if df contains the following values:
#   A B C
# 0 3 5 1
# 1 8 2 7
# 2 6 9 4
# 3 2 3 5
# 4 9 1 2
# Your function should select the following rows: A B C
# 1 8 2 7
# 4 9 1 2
# The function should return a new DataFrame that contains only the selected rows.

# %%
df = pd.DataFrame({'A': [3, 8, 6, 2, 9],
                   'B': [5, 2, 9, 3, 1],
                   'C': [1, 7, 4, 5, 2]})
df
# Out:
#    A  B  C
# 0  3  5  1
# 1  8  2  7
# 2  6  9  4
# 3  2  3  5
# 4  9  1  2

# %%
def filter_df(df):
    selected_rows = df[(df['A'] > 5) & (df['B'] < 10)]

    return selected_rows

filter_df(df)
# Out:
#    A  B  C
# 1  8  2  7
# 2  6  9  4
# 4  9  1  2

# %% [markdown]
# Q9. Given a Pandas DataFrame df with a column 'Values', write a Python function to calculate the mean,
# median, and standard deviation of the values in the 'Values' column.

# %%
df = pd.DataFrame({'Values' : [1,2,3,4,55,67]})
df
# Out:
#    Values
# 0       1
# 1       2
# 2       3
# 3       4
# 4      55
# 5      67

# %%
def calc(df):
    print(f'Mean: {df["Values"].mean()}')
    print(f'Median: {df["Values"].median()}')
    print(f'Standard Deviation: {df["Values"].std()}')

calc(df)
# Out:
# Mean: 22.0
# Median: 3.5
# Standard Deviation: 30.463092423455635

# %% [markdown]
# Q10. Given a Pandas DataFrame df with a column 'Sales' and a column 'Date', write a Python function to
# create a new column 'MovingAverage' that contains the moving average of the sales for the past 7 days
# for each row in the DataFrame. The moving average should be calculated using a window of size 7 and
# should include the current day.

# %%
df = pd.DataFrame({'Sales': [10, 15, 12, 8, 20, 18, 25, 22, 30, 28],
                   'Date': ['2023-06-01', '2023-06-02', '2023-06-03', '2023-06-04', '2023-06-05',
                            '2023-06-06', '2023-06-07', '2023-06-08', '2023-06-09', '2023-06-10']})
df
# Out:
#    Sales        Date
# 0     10  2023-06-01
# 1     15  2023-06-02
# 2     12  2023-06-03
# 3      8  2023-06-04
# 4     20  2023-06-05
# 5     18  2023-06-06
# 6     25  2023-06-07
# 7     22  2023-06-08
# 8     30  2023-06-09
# 9     28  2023-06-10

# %%
def calc_moving_avg(df):
    # Convert the 'Date' column to datetime
    df['Date'] = pd.to_datetime(df['Date'])
        
    # Sort the DataFrame by date in ascending order
    df = df.sort_values('Date')
    
    # Calculate the moving average using a window of size 7
    df['MovingAverage'] = df['Sales'].rolling(window=7, min_periods=1).mean()
    
    return df

calc_moving_avg(df)
# Out:
#    Sales       Date  MovingAverage
# 0     10 2023-06-01      10.000000
# 1     15 2023-06-02      12.500000
# 2     12 2023-06-03      12.333333
# 3      8 2023-06-04      11.250000
# 4     20 2023-06-05      13.000000
# 5     18 2023-06-06      13.833333
# 6     25 2023-06-07      15.428571
# 7     22 2023-06-08      17.142857
# 8     30 2023-06-09      19.285714
# 9     28 2023-06-10      21.571429

# %% [markdown]
# Q11. You have a Pandas DataFrame df with a column 'Date'. Write a Python function that creates a new
# column 'Weekday' in the DataFrame. The 'Weekday' column should contain the weekday name (e.g.
# Monday, Tuesday) corresponding to each date in the 'Date' column.
# For example, if df contains the following values:
# Date
# 0 2023-01-01
# 1 2023-01-02
# 2 2023-01-03
# 3 2023-01-04
# 4 2023-01-05
# Your function should create the following DataFrame:
#
# Date Weekday
# 0 2023-01-01 Sunday
# 1 2023-01-02 Monday
# 2 2023-01-03 Tuesday
# 3 2023-01-04 Wednesday
# 4 2023-01-05 Thursday
# The function should return the modified DataFrame.

# %%
df = pd.DataFrame({'Date': ['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05']})
df
# Out:
#          Date
# 0  2023-01-01
# 1  2023-01-02
# 2  2023-01-03
# 3  2023-01-04
# 4  2023-01-05

# %%
def weekday(df):
     # Convert the 'Date' column to datetime
    df['Date'] = pd.to_datetime(df['Date'])
    
    # Extract the weekday name from the 'Date' column
    df['Weekday'] = df['Date'].dt.day_name()

    return df

weekday(df)
# Out:
#         Date    Weekday
# 0 2023-01-01     Sunday
# 1 2023-01-02     Monday
# 2 2023-01-03    Tuesday
# 3 2023-01-04  Wednesday
# 4 2023-01-05   Thursday

# %% [markdown]
# Q12. Given a Pandas DataFrame df with a column 'Date' that contains timestamps, write a Python
# function to select all rows where the date is between '2023-01-01' and '2023-01-31'.

# %%
df = pd.DataFrame({'Date': ['2022-12-31T23:59:59', '2023-01-01T12:00:00', '2023-01-15T09:30:00', '2023-01-31T18:45:00', '2023-02-15T10:00:00']})
df
# Out:
#                   Date
# 0  2022-12-31T23:59:59
# 1  2023-01-01T12:00:00
# 2  2023-01-15T09:30:00
# 3  2023-01-31T18:45:00
# 4  2023-02-15T10:00:00

# %%
import pandas as pd

def select_rows_by_timestamp(df):
    # Convert the 'Date' column to datetime
    df['Date'] = pd.to_datetime(df['Date'])

    # Define the start and end timestamps of the range
    start_date = pd.to_datetime('2023-01-01')
    end_date = pd.to_datetime('2023-01-31')

    # Use boolean indexing to select rows within the date range
    selected_rows = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]

    # Return the selected rows as a new DataFrame
    return selected_rows

# Select rows within the timestamp range
selected_df = select_rows_by_timestamp(df)

# Print the selected rows
print(selected_df)
# Out:
#                  Date
# 1 2023-01-01 12:00:00
# 2 2023-01-15 09:30:00

# %% [markdown]
# Q13. To use the basic functions of pandas, what is the first and foremost necessary library that needs to
# be imported?

# %% [markdown]
# The first and foremost library that needs to be imported to use the basic functions of pandas is the pandas library itself. Once you have imported the pandas library, you can access its functions and objects to perform various data manipulation and analysis tasks.

# %%
import pandas as pd
