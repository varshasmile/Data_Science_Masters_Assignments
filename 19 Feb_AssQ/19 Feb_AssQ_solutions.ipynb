# %% [markdown]
# Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# Flask is a lightweight and flexible web framework for Python. It provides tools and libraries to build web applications quickly and efficiently.
#
# Advantages of Flask Framework:
#
# 1. Lightweight and minimalistic approach.
# 2. Easy to get started with a small learning curve.
# 3. Modular and extensible design with various libraries and extensions available.
# 4. Flexibility in project structure and design patterns.
# 5. Large and active community support.
# 6. Well-suited for small to medium-sized projects or prototypes.

# %% [markdown]
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.

# %%
from flask import Flas

app = Flask(__name__)

@app.route("/")
def hello_world():
    return "<h1>Hello World!!</h1>"

if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![Screenshot (189).png](attachment:d22b66e4-9075-435f-b7f0-ecd815c8ba3d.png)

# %% [markdown]
# Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# In Flask, app routing refers to the process of mapping URL paths to specific functions or views within a Flask application. It allows defining routes or endpoints that determine how different URLs will be handled by the application.
#
# App routing in Flask is accomplished using the @app.route() decorator. This decorator is used to associate a URL path with a function that will be executed when that specific URL is requested.
#
# We use app routes in Flask to create a URL structure for our web application. Each route defines a specific functionality or page within the application. It allows users to access different views or perform different actions based on the URL they visit. By associating routes with functions, we can organize and handle the logic for each route efficiently. App routing provides a clean and structured way to handle different URLs and manage the flow of the application.

# %% [markdown]
# Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
# Company Name: ABC Corporation
# Location: India
# Contact Detail: 999-999-9999
# Attach the screenshot of the output in Jupyter Notebook.

# %%
from flask import Flask

app = Flask(__name__)

@app.route('/welcome')
def welcome():
    return 'Welcome to ABC Corporation'

@app.route('/')
def company_details():
    details = '''
    Company Name: ABC Corporation
    Location: India
    Contact Detail: 999-999-9999
    '''
    return details

if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![Screenshot (190).png](attachment:a01c9c89-430b-43b1-91a9-ac84efc4a205.png)
# ![Screenshot (191).png](attachment:448e3f19-7d2a-4a2a-8f99-e5081ec93aa6.png)

# %% [markdown]
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
# url_for() function.

# %% [markdown]
# In Flask, the url_for() function is used for URL building. It generates a URL for a given endpoint (view function) by taking into account the defined routes in the Flask application.
#
# Here's an example Python code to demonstrate the working of the url_for() function in Flask:

# %%
from flask import Flask, url_for

app = Flask(__name__)

@app.route('/')
def index():
    return 'This is the homepage'

@app.route('/user/<username>')
def user_profile(username):
    return f'Hello, {username}'

@app.route('/products')
def products():
    return 'This is the products page'

if __name__ == '__main__':
    with app.test_request_context():
        # Generate URLs using url_for()
        homepage_url = url_for('index')
        user_url = url_for('user_profile', username='john')
        products_url = url_for('products')

        # Print the generated URLs
        print("Homepage URL:", homepage_url)
        print("User URL:", user_url)
        print("Products URL:", products_url)
# Out:
# Homepage URL: /
# User URL: /user/john
# Products URL: /products
